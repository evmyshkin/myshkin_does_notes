# %% [markdown]
# # Explain Analyze
# Команда `EXPLAIN` предсказывает этапы и длительность выполнения запроса. Принимает выражение SQL в качестве аргумента.
#  Также, вместе с `EXPLAIN` можно вызвать команду `ANALYZE` для фактических замеров исполнения команды
#  ```SQL
