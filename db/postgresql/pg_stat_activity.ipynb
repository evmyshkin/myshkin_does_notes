# %% [markdown]
# # pg_stat_activity
#
# Посмотреть вью всех серверные процессы и их транзакции
# ```sql
# SELECT * FROM pg_stat_activity;
# ```

# %% [markdown]
# Посмотреть активные транзакции
# ```sql
# SELECT * FROM pg_stat_activity where state = 'active';
# ```

# %% [markdown]
# Посмотреть локи
# ```sql
# SELECT * FROM pg_catalog.pg_locks;
# ```
